# %% [markdown]
# ## SQL Operations

# %% [markdown]
# ### 1. Import the cleaned dataset into a SQL database.

# %% [markdown]
# Using MySQL Workbench
# * Created a database/schema to store the csv file

# %% [markdown]
# ## ![Screenshot 2025-08-03 123358.png](<attachment:Screenshot 2025-08-03 123358.png>)

# %% [markdown]
# ## ![Screenshot 2025-08-02 005512.png](<attachment:Screenshot 2025-08-02 005512.png>)

# %% [markdown]
# ## ![Screenshot 2025-08-03 123451.png](<attachment:Screenshot 2025-08-03 123451.png>)

# %% [markdown]
# ## ![Screenshot 2025-08-03 124508.png](<attachment:Screenshot 2025-08-03 124508.png>)

# %% [markdown]
# * Importing the cleaned dataset

# %% [markdown]
# ## ![Screenshot 2025-08-03 123650.png](<attachment:Screenshot 2025-08-03 123650.png>)

# %% [markdown]
# ## ![Screenshot 2025-08-03 125948.png](<attachment:Screenshot 2025-08-03 125948.png>)

# %% [markdown]
# ## ![Screenshot 2025-08-03 130011.png](<attachment:Screenshot 2025-08-03 130011.png>)

# %% [markdown]
# ## ![Screenshot 2025-08-03 130041.png](<attachment:Screenshot 2025-08-03 130041.png>)

# %% [markdown]
# ## ![Screenshot 2025-08-03 130123.png](<attachment:Screenshot 2025-08-03 130123.png>)

# %% [markdown]
# * Action Output

# %% [markdown]
# ## ![Screenshot 2025-08-02 010205.png](<attachment:Screenshot 2025-08-02 010205.png>)

# %% [markdown]
# * Using the database created and Select Query to view the table

# %%
# USE performance;
# SELECT * FROM student_data;

# %% [markdown]
# ## ![Screenshot 2025-08-02 010648.png](<attachment:Screenshot 2025-08-02 010648.png>)

# %% [markdown]
# ### 2. Write SQL queries to:

# %% [markdown]
# #### o List top 5 students with highest average scores

# %% [markdown]
# Query :

# %%
# SELECT * FROM student_data ORDER BY average_score DESC LIMIT 5;

# %% [markdown]
# Output :

# %% [markdown]
# ## ![Screenshot 2025-08-03 132240.png](<attachment:Screenshot 2025-08-03 132240.png>)

# %% [markdown]
# #### o Find the average math, reading, and writing scores by gender.

# %% [markdown]
# Query :

# %%
# SELECT gender,
#   AVG(`math score`)    AS avg_math_score,
#   AVG(`reading score`) AS avg_reading_score,
#   AVG(`writing score`) AS avg_writing_score
# FROM student_data
# GROUP BY gender;

# %% [markdown]
# Output :

# %% [markdown]
# ## ![Screenshot 2025-08-02 151855.png](<attachment:Screenshot 2025-08-02 151855.png>)

# %% [markdown]
# #### o Compare average scores of students who completed test prep vs. those who didn’t.

# %% [markdown]
# Query :

# %%
# SELECT `test preparation course` AS test_prep_status,
#   AVG(`math score`) AS avg_math_score,
#   AVG(`reading score`) AS avg_reading_score,
#   AVG(`writing score`) AS avg_writing_score
# FROM student_data
# GROUP BY `test preparation course`;

# %% [markdown]
# Output :

# %% [markdown]
# ## ![Screenshot 2025-08-02 152258.png](<attachment:Screenshot 2025-08-02 152258.png>)

# %% [markdown]
# #### o Count how many students fall into each performance category.

# %% [markdown]
# Query :

# %%
# SELECT performance_category,
#   COUNT(*) AS students_count
# FROM student_data
# GROUP BY performance_category
# ORDER BY FIELD(performance_category,'High','Medium','Low');

# %% [markdown]
# Output :

# %% [markdown]
# ## ![Screenshot 2025-08-02 153410.png](<attachment:Screenshot 2025-08-02 153410.png>)

# %% [markdown]
# #### o Identify which ethnic group has the highest average total score.

# %% [markdown]
# Query :

# %%
# SELECT `race/ethnicity` ,
#   AVG(average_score * 3) AS avg_total_score
# FROM student_data
# GROUP BY `race/ethnicity`
# ORDER BY avg_total_score DESC
# LIMIT 1;

# %% [markdown]
# Output :

# %% [markdown]
# ## ![Screenshot 2025-08-02 154228.png](<attachment:Screenshot 2025-08-02 154228.png>)
